# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
cd /gdrive/My\ Drive
# Out:
# /gdrive/My Drive

# %%
 cd data/
# Out:
# /gdrive/My Drive/data

# %%
import pandas as pd
data=pd.read_csv('./Features_train4.csv')

# %%
data
# Out:
#       Unnamed: 0  target  flux_min  ...   tflux_i   tflux_z   tflux_y
# 0              0      92  0.998599  ...  0.020112  0.017101  0.015200
# 1              1      88  0.999543  ...  0.000990  0.000886  0.000806
# 2              2      42  0.999539  ...  0.000000  0.000000  0.000000
# 3              3      90  0.999542  ...  0.000000  0.000000  0.000000
# 4              4      90  0.999541  ...  0.000000  0.000000  0.000000
# 5              5      65  0.999545  ...  0.001588  0.003789  0.006363
# 6              6      90  0.999544  ...  0.000000  0.000000  0.000000
# 7              7      42  0.999543  ...  0.000000  0.000000  0.000000
# 8              8      90  0.999544  ...  0.000000  0.000000  0.000000
# 9              9      65  0.999510  ...  0.014803  0.029374  0.044092
# 10            10      90  0.999540  ...  0.000000  0.000000  0.000000
# 11            11      42  0.999541  ...  0.000000  0.000000  0.000000
# 12            12      42  0.999541  ...  0.000000  0.000000  0.000000
# 13            13      90  0.999542  ...  0.000000  0.000000  0.000000
# 14            14      65  0.999534  ...  0.049951  0.099089  0.148711
# 15            15      16  0.999367  ...  0.026710  0.017793  0.007306
# 16            16      67  0.999541  ...  0.000000  0.000000  0.000000
# 17            17      67  0.999543  ...  0.000000  0.000000  0.000000
# 18            18      42  0.999544  ...  0.000000  0.000000  0.000000
# 19            19      95  0.999547  ...  0.000000  0.000000  0.000000
# 20            20      88  0.999542  ...  0.000306  0.000259  0.000267
# 21            21      62  0.999538  ...  0.000000  0.000000  0.000000
# 22            22      88  0.999438  ...  0.001470  0.001435  0.002018
# 23            23      42  0.999536  ...  0.000000  0.000000  0.000000
# 24            24      16  0.999435  ...  0.001593  0.000952  0.000364
# 25            25      15  0.999538  ...  0.000000  0.000000  0.000000
# 26            26      42  0.999522  ...  0.000000  0.000000  0.000000
# 27            27      90  0.999546  ...  0.000000  0.000000  0.000000
# 28            28      90  0.999539  ...  0.000000  0.000000  0.000000
# 29            29      90  0.999547  ...  0.000000  0.000000  0.000000
# ...          ...     ...       ...  ...       ...       ...       ...
# 7818        7818       6  0.999416  ...  0.006650  0.007111  0.007086
# 7819        7819      42  0.999441  ...  0.000000  0.000000  0.000000
# 7820        7820      90  0.999485  ...  0.000000  0.000000  0.000000
# 7821        7821      16  0.995990  ...  0.044872  0.024487  0.008813
# 7822        7822      42  0.999491  ...  0.000000  0.000000  0.000000
# 7823        7823      65  0.999483  ...  0.010777  0.021361  0.032043
# 7824        7824      52  0.999474  ...  0.000000  0.000000  0.000000
# 7825        7825      90  0.999516  ...  0.000000  0.000000  0.000000
# 7826        7826      65  0.999487  ...  0.008630  0.013461  0.015429
# 7827        7827      15  0.999518  ...  0.000000  0.000000  0.000000
# 7828        7828      16  0.999453  ...  0.110270  0.073352  0.030080
# 7829        7829      90  0.999487  ...  0.000000  0.000000  0.000000
# 7830        7830      16  0.998898  ...  0.014066  0.009159  0.003702
# 7831        7831      42  0.999506  ...  0.000000  0.000000  0.000000
# 7832        7832      15  0.999517  ...  0.000000  0.000000  0.000000
# 7833        7833      52  0.999497  ...  0.000000  0.000000  0.000000
# 7834        7834      65  0.999464  ...  0.044913  0.066021  0.073804
# 7835        7835      62  0.999476  ...  0.000000  0.000000  0.000000
# 7836        7836      42  0.999533  ...  0.000000  0.000000  0.000000
# 7837        7837      64  0.999509  ...  0.000000  0.000000  0.000000
# 7838        7838      16  0.999274  ...  0.105977  0.065717  0.025718
# 7839        7839      15  0.999462  ...  0.000000  0.000000  0.000000
# 7840        7840      67  0.999478  ...  0.000000  0.000000  0.000000
# 7841        7841      16  0.999496  ...  0.001491  0.000805  0.000288
# 7842        7842      65  0.999484  ...  0.001617  0.003240  0.004906
# 7843        7843      65  0.999464  ...  0.021802  0.036229  0.042621
# 7844        7844      90  0.999496  ...  0.000000  0.000000  0.000000
# 7845        7845      16  0.999438  ...  0.007882  0.005086  0.002049
# 7846        7846      65  0.999510  ...  0.001616  0.003204  0.004807
# 7847        7847       6  0.999480  ...  0.272982  0.257889  0.236974
#
# [7848 rows x 370 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'target', 'flux_min', 'flux_max', 'flux_mean',
#        'flux_median', 'flux_std', 'flux_skew', 'flux_err_min', 'flux_err_max',
#        ...
#        'true_rv', 'true_av', 'true_peakmjd', 'libid_cadence', 'tflux_u',
#        'tflux_g', 'tflux_r', 'tflux_i', 'tflux_z', 'tflux_y'],
#       dtype='object', length=370)

# %%
data.shape
# Out:
# (7848, 370)

# %%
 data=data.drop(columns=['Unnamed: 0'])
 data.columns
# Out:
# Index(['target', 'flux_min', 'flux_max', 'flux_mean', 'flux_median',
#        'flux_std', 'flux_skew', 'flux_err_min', 'flux_err_max',
#        'flux_err_mean',
#        ...
#        'true_rv', 'true_av', 'true_peakmjd', 'libid_cadence', 'tflux_u',
#        'tflux_g', 'tflux_r', 'tflux_i', 'tflux_z', 'tflux_y'],
#       dtype='object', length=369)

# %%
import numpy as np

from scipy.stats import uniform, randint

from sklearn.datasets import load_breast_cancer, load_diabetes, load_wine
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split

import xgboost as xgb

# %%
def display_scores(scores):
    print("Scores: {0}\nMean: {1:.3f}\nStd: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
# X_train=pd.read_csv('./X_train.csv')
# X_train=X_train.drop(columns=['Unnamed: 0'])
# y_train=pd.read_csv('./y_train.csv')
# y_train=y_train.drop(columns=['Unnamed: 0'])
# X_test=pd.read_csv('./X_test.csv')
# X_test=X_test.drop(columns=['Unnamed: 0'])
# y_test=pd.read_csv('./y_test.csv')
# y_test=y_test.drop(columns=['Unnamed: 0'])

# %%
# # diabetes = load_diabetes()

# # X = diabetes.data
# # y = diabetes.target

# xgb_model = xgb.XGBRegressor()

# params = {
#     "colsample_bytree": uniform(0.7, 0.3),
#     "gamma": uniform(0, 0.5),
#     "learning_rate": uniform(0.03, 0.3), # default 0.1 
#     "max_depth": randint(2, 6), # default 3
#     "n_estimators": randint(100, 150), # default 100
#     "subsample": uniform(0.6, 0.4)
# }


# search = RandomizedSearchCV(xgb_model, param_distributions=params, random_state=42, n_iter=200, cv=3, verbose=1, n_jobs=1, return_train_score=True)

# search.fit(X_train, y_train)
# report_best_scores(search.cv_results_, 1)

# %%
ls
# Out:
#  0001.model              'note1_dataRelease.pdf?download=1'
#  best_boston.pkl         'note2_modelNames.pdf?download=1'
#  cesium/                 'note2_modelNames.pdf?download=1.gdoc'
# ' Features_train22.csv'  'N&Sh_features.csv'
#  Features_train4.csv      plasticc_featuretable.npz
#  Features_train6.csv      plasticc_test_lightcurves_02.csv
# 'flux over time2.png'     plasticc_test_lightcurves_03.csv
# 'flux over time3.png'     plasticc_test_lightcurves_04.csv
# 'flux over time.png'      plasticc_test_metadata.csv
#  keras.model              plasticc_train_lightcurves.csv
#  mahya_test.jpg           plasticc_train_metadata.csv
#  mahya_test_XGBoost.jpg  'single_output_test_ts_features (1).csv'
#  mahya_XGBoost1.jpg       single_output_test_ts_features.csv*
#  naive_benchmark.csv      single_output_test_ts_features.csv.zip
#  nazi.csv                 xgb_model
#  nazi_full.csv           'xgb_model (1)'/
#  nazi_priod.csv           X_test.csv
#  nazi_tarin.csv           X_train.csv
#  nazi_test.csv            y_test.csv
#  node_modules/            y_train.csv

# %%
# # cancer = load_breast_cancer()

# # X = cancer.data
# # y = cancer.target

# # if more than one evaluation metric are given the last one is used for early stopping
# xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42, eval_metric="auc")

# # X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# xgb_model.fit(X_train, y_train, early_stopping_rounds=5, eval_set=[(X_test, y_test)])

# y_pred = xgb_model.predict(X_test)

# accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-20-cef94f7fd6d7> in <module>()
#       3 # X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#       4
# ----> 5 xgb_model.fit(X_train, y_train, early_stopping_rounds=5, eval_set=[(X_test, y_test)])
#       6
#       7 y_pred = xgb_model.predict(X_test)
#
# /usr/local/lib/python3.6/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      82         # check evaluation result.
#      83         if evals:
# ---> 84             bst_eval_set = bst.eval_set(evals, i, feval)
#      85             if isinstance(bst_eval_set, STRING_TYPES):
#      86                 msg = bst_eval_set
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in eval_set(self, evals, iteration, feval)
#    1170                                               dmats, evnames,
#    1171                                               c_bst_ulong(len(evals)),
# -> 1172                                               ctypes.byref(msg)))
#    1173         res = msg.value.decode()
#    1174         if feval is not None:
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in _check_call(ret)
#     174     """
#     175     if ret != 0:
# --> 176         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     177
#     178
#
# XGBoostError: [16:58:45] /workspace/src/metric/rank_metric.cc:150: Check failed: preds.Size() == info.labels_.Size() (27468 vs. 1962) : label size predict size not match
# Stack trace:
#   [bt] (0) /usr/local/lib/python3.6/dist-packages/xgboost/./lib/libxgboost.so(dmlc::LogMessageFatal::~LogMessageFatal()+0x24) [0x7fea6048ecb4]
#   [bt] (1) /usr/local/lib/python3.6/dist-packages/xgboost/./lib/libxgboost.so(+0x1be51d) [0x7fea6054c51d]
#   [bt] (2) /usr/local/lib/python3.6/dist-packages/xgboost/./lib/libxgboost.so(xgboost::LearnerImpl::EvalOneIter(int, std::vector<xgboost::DMatrix*, std::allocator<xgboost::DMatrix*> > const&, std::vector<std::string, std::allocator<std::string> > const&)+0x3c9) [0x7fea60528d99]
#   [bt] (3) /usr/local/lib/python3.6/dist-packages/xgboost/./lib/libxgboost.so(XGBoosterEvalOneIter+0x371) [0x7fea6048b651]
#   [bt] (4) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call_unix64+0x4c) [0x7fea944dddae]
#   [bt] (5) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call+0x22f) [0x7fea944dd71f]
#   [bt] (6) /usr/lib/python3.6/lib-dynload/_ctypes.cpython-36m-x86_64-linux-gnu.so(_ctypes_callproc+0x2b4) [0x7fea946f1c64]
#   [bt] (7) /usr/lib/python3.6/lib-dynload/_ctypes.cpython-36m-x86_64-linux-gnu.so(+0x122e3) [0x7fea946f22e3]
#   [bt] (8) /usr/bin/python3(_PyObject_FastCallKeywords+0x19c) [0x57ec0c]

# %%
print("best score: {0}, best iteration: {1}, best ntree limit {2}".format(xgb_model.best_score, xgb_model.best_iteration, xgb_model.best_ntree_limit))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-13612c0936b3> in <module>()
# ----> 1 print("best score: {0}, best iteration: {1}, best ntree limit {2}".format(xgb_model.best_score, xgb_model.best_iteration, xgb_model.best_ntree_limit))
#
# AttributeError: 'XGBClassifier' object has no attribute 'best_score'

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[52  2]
#  [ 4 85]]

# %%
import pylab as plt

# %%
def conf_plotter(y_true, y_pred, classes,
                      normalize=0,
                      title=None,
                      cmap=plt.cm.pink_r,
                      mode = 'train',
                      save = 0,
                      name = 'conf.jpg'):

    if not title:
        if mode == 'train':
            title = 'Normalized confusion matrix on train dataset'
        else:
            title = 'Normalized confusion matrix on test dataset'
            

    from sklearn.metrics import confusion_matrix
    
    cm = confusion_matrix(y_true, y_pred)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    fig, ax = plt.subplots(figsize=(10,10))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax ,fraction=0.046, pad=0.04)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           xlabel='Predicted label',
           ylabel='True label')
    
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] ):
                    
        item.set_fontsize(20)
     
    for item in (ax.get_xticklabels() + ax.get_yticklabels()):
        
        item.set_fontsize(12)

        
                
    plt.gca().invert_yaxis()
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    if save == 1:
        plt.savefig(name)
    return ax

# %%
targets = data['target']
classes = targets.unique()
classes
# Out:
# array([92, 88, 42, 90, 65, 16, 67, 95, 62, 15, 52,  6, 64, 53])

# %%
class_map =[] 

for i,val in enumerate(classes):
    class_map.append([val , i])

# %%
labels = [class_map[i][0] for i in range(len(class_map))]  
conf_plotter(y_test , y_pred , labels , normalize=1, mode='test' , cmap = plt.cm.RdPu,save=1 , name='mahya_test_XGBoost.jpg')

# %%
# digits = load_digits()
# y = digits['target']
# X = digits['data']
kf = KFold(n_splits=5, shuffle=True, random_state=rng)
for train_index, test_index in kf.split(X):
    xgb_model = xgb.XGBClassifier().fit(X[train_index], y[train_index])
    predictions = xgb_model.predict(X[test_index])
    actuals = y[test_index]
    print(confusion_matrix(actuals, predictions))

print("Iris: multiclass classification")
# iris = load_iris()
# y = iris['target']
# X = iris['data']
kf = KFold(n_splits=2, shuffle=True, random_state=rng)
for train_index, test_index in kf.split(X):
    xgb_model = xgb.XGBClassifier().fit(X[train_index], y[train_index])
    predictions = xgb_model.predict(X[test_index])
    actuals = y[test_index]
    print(confusion_matrix(actuals, predictions))

print("Boston Housing: regression")
# boston = load_boston()
# y = boston['target']
# X = boston['data']
kf = KFold(n_splits=2, shuffle=True, random_state=rng)
for train_index, test_index in kf.split(X):
    xgb_model = xgb.XGBRegressor().fit(X[train_index], y[train_index])
    predictions = xgb_model.predict(X[test_index])
    actuals = y[test_index]
    print(mean_squared_error(actuals, predictions))

print("Parameter optimization")
# y = boston['target']
# X = boston['data']
xgb_model = xgb.XGBRegressor()
clf = GridSearchCV(xgb_model,
                   {'max_depth': [2,4,6],
                    'n_estimators': [50,100,200]}, verbose=1)
clf.fit(X,y)
print(clf.best_score_)
print(clf.best_params_)

# The sklearn API models are picklable
print("Pickling sklearn API models")
# must open in binary format to pickle
pickle.dump(clf, open("best_boston.pkl", "wb"))
clf2 = pickle.load(open("best_boston.pkl", "rb"))
print(np.allclose(clf.predict(X), clf2.predict(X)))

# Early-stopping

# X = digits['data']
# y = digits['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
clf = xgb.XGBClassifier()
clf.fit(X_train, y_train, early_stopping_rounds=10, eval_metric="auc",
        eval_set=[(X_test, y_test)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f2cc5e219a36> in <module>()
# ----> 1 kf = KFold(n_splits=5, shuffle=True, random_state=rng)
#       2 for train_index, test_index in kf.split(X):
#       3     xgb_model = xgb.XGBClassifier().fit(X[train_index], y[train_index])
#       4     predictions = xgb_model.predict(X[test_index])
#       5     actuals = y[test_index]
#
# NameError: name 'rng' is not defined
